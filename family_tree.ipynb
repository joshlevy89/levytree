# %%
# TODO: B2 side 
with open('/Users/levyjos/Desktop/levy_family_tree.txt', encoding="ISO-8859-1") as f:
    for line in f:
        line = line.strip()
        if line.startswith('B1'):
            print(line)
        # TODO: handle marriages ...or line.startswith('m'):
# Out:
# B1. Menachem Cantos (b: Greece)
# B1a. David Cantos b: Ioannina Greece; d: Florida (married, no children)
# B1b. Malka Cantos b: 1870; d: 1902 (Ioannina Greece)
# B1b1. Haim Joseph Yomtov b: 1894; d: 1968 (NY)
# B1b1a. Joseph Yomtov b: 02.10.1937
# B1b1a1. David Yomtov b: 1959
# B1b1a2. Anna Yomtov b: 1965
# B1b1a3. Naomi Yomtov
# B1b1a3a. Nathan Odenkirk b: 1998
# B1b1b. Morris Yomtov b: 1941
# B1b1c. Sarah Yomtov b: 1944
# B1b1c1. Benjamin Lopez then Benjamin Yomtov b: 1973
# B1b1c1a. Maxx Yomtov b: 04.06.2006
# B1b1c2. Hannah Lopez b: 1979
# B1b1c3. Jesse Lopez b: 1982
# B1b2. Menachem Joseph Yomtov b: 12.18.1896 (Ioannina Greece); d: 12.22.1961 (NY)
# B1b2a. Joseph Yomtov b: 02.11.1930
# B1b2b. Morris Yomtov b: 08.11.1931
# B1b2c. Renee Yomtov b: 05.29.1937 (NY)
# B1b2c1. David Menachem Rosenthal b: 12.05.1964 (Brooklyn NY)
# B1b2c2. Joshua Ira Rosenthal g: 05.31.1967 (Brooklyn NY)
# B1b2c2a. Emma Pearl Rosenthal b: 10.19.2001 (New York City)
# ...

# %%
# line = 'B1b2. Menachem Joseph Yomtov b: 12.18.1896 (Ioannina Greece); d: 12.22.1961 (NY)'
# line = 'B1b1c. Sarah Yomtov b: 1944'
line = 'B1b1a3. Naomi Yomtov'
# line = 'm: 2004 Thad Dingman'
line.split('. ')[1].split(' b:')[0]
# Out:
# 'Naomi Yomtov'
